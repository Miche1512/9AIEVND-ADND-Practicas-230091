# %% [markdown]
# # Practica 04: Analisis de Datos Exploratorio con Python y Jupiter Notebook en un Dataset de Productos de Amazon store

# %% [markdown]
# **Programa de Estudios:** Ingenieria en Entornos Virtuales y Negocios Digitales\
# **Asignatura:** Analitica de Datos para Negocios Digitales \
# **Docente:** M.T.I. Marco A. Ramirez Hernández \
# **Periodo:** Mayo - Agosto 2026

# %% [markdown]
# ### Unidad 2: Preparacion de los Datos

# %% [markdown]
# **Nombre del estudiante:** Michelle De La Cruz Rosalino \
# **Matricula:** 230091 \
# **Grado y Grupo:** 9A IEVND

# %% [markdown]
# <div style="background: linear-gradient(135deg, #FF9900 0%, #232F3E 100%); padding: 30px;border-radius: 15px; text-align: center;margin-bottom:20px;"><h1 style="color: white; font-size: 2.2em; margin: 0;"> Productos de Amazon Store - Analisis Exploratorio de Datos Completo & Aprendizaje Automatico Predictivo (ML)</h1>
# <p style="color: #FFD700; font-size: 1.1em; margin-top: 10px;">Prediccion de Precisos - Analisis de Categorias - Ingenieria de Funcionalidades - Comparacion de Modeles</p>
# </div>

# %% [markdown]
# ## Tabla de Contenidos
# | # | seccion | Descripcion |
# |---|---|---|
# | 1 | [Instalaciones y carga de Datos](#s1) | Librerias, carga de CSV, Primeros comandos de estructura |

# %% [markdown]
# ## Instalaciones & carga de Datos <a id='s1'></a>
#
# <div style="background:#f0f8ff; padding:12px; border-left:4px solid #FF9900; BORDER-RADIUS:5px00; color: #0066cc;">
# <b>Dataset:</b>Amazon India Lista de Productos - 1,436 productos entre Libros, Kindle, Deportes & mas<br>
# <b>Objetivo:</b> Predecir el Precio del Producto (INR) desde la categoria, longitud del nombre, y disponibilidad <br>
# <b>DataSource:</b> Web-scraped de paginas de productos Amazon.in
# </div>

# %%
# ===================================================
# SELECTION 1 - Setup & Data Loading
# ===================================================

import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import warnings

print(f'✅ Pandas : {pd.__version__}')
print(f'✅ Numpy : {np.__version__}')
print('✅Todas las librerias cargaron con exito!')
# Out:
# ✅ Pandas : 2.3.3
# ✅ Numpy : 2.3.5
# ✅Todas las librerias cargaron con exito!

# %%
# Load dataset
df_raw = pd.read_csv('./amazon_products_data.csv', encoding='latin-1')
print(f' Shape : {df_raw.shape}')
print(f' Columns : {df_raw.columns.tolist()}')
df_raw.head(3)
# Out:
#  Shape : (1436, 17)
#  Columns : ['rl', 'asin', 'name', 'overview', 'price', 'currency', 'availability', 'brand', 'about_item', 'img_source', 'description', 'specifications', 'primary_category', 'category_1', 'category_2', 'category_3', 'breadcrumbs']
#                                     rl        asin  \
# 0  https://www.amazon.in/dp/1788832566  1788832566
# 1  https://www.amazon.in/dp/0766199592  0766199592
# 2  https://www.amazon.in/dp/B071ZCD9XH  B071ZCD9XH
#
#                                                 name overview     price  \
# 0  Hands-On Design Patterns with C++: Solve commo...       []  1,600.00
# 1  The Blazing Horizon The True Story of Pawnee B...       []  2,399.00
# 2  Fast and easy lunch box: A collection of 15eas...       []       NaN
#
#   currency                          availability  \
# 0      INR                                   NaN
# 1      INR  Usually dispatched in 13 to 14 days.
# 2      NaN                                   NaN
#
#                                                brand about_item  \
# 0  by               \n        Fedor G. Pikus  (Au...        NaN
# 1          by               \nErnest Lynn \n(Author)        NaN
# 2  by                    \nNinety Nine Cents Pres...        NaN
#
#                                           img_source description  \
# 0  https://images-na.ssl-images-amazon.com/images...         NaN
# 1  https://images-na.ssl-images-amazon.com/images...         NaN
# 2  https://m.media-amazon.com/images/I/41g9Z21QuG...         NaN
#
#   specifications primary_category            category_1  \
# 0             []            Books  Computers & Internet
# 1             []            Books    Action & Adventure
# 2             []     Kindle Store         Kindle eBooks
#
#                            category_2 category_3  \
# 0  Programming & Software Development        NaN
# 1                                 NaN        NaN
# 2            Crafts, Home & Lifestyle        NaN
#
#                                          breadcrumbs
# 0  Books | Computers & Internet | Programming & S...
# 1                         Books | Action & Adventure
# 2  Kindle Store | Kindle eBooks | Crafts, Home & ...
